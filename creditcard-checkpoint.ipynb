# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Importing File And Exploratory Data Analysis

# %%
df = pd.read_csv('./Downloads/creditcardfraud/creditcard.csv')

# %%
df.shape
# Out:
# (284807, 31)

# %%
df.index
# Out:
# RangeIndex(start=0, stop=284807, step=1)

# %%
df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
df.tail()
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V21       V22  \
# 284802 -2.606837 -4.918215  7.305334  1.914428  ...  0.213454  0.111864
# 284803  1.058415  0.024330  0.294869  0.584800  ...  0.214205  0.924384
# 284804  3.031260 -0.296827  0.708417  0.432454  ...  0.232045  0.578229
# 284805  0.623708 -0.686180  0.679145  0.392087  ...  0.265245  0.800049
# 284806 -0.649617  1.577006 -0.414650  0.486180  ...  0.261057  0.643078
#
#              V23       V24       V25       V26       V27       V28  Amount  \
# ...

# %%
df.describe()
# Out:
#                 Time            V1            V2            V3            V4  \
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean    94813.859575  1.165980e-15  3.416908e-16 -1.373150e-15  2.086869e-15
# std     47488.145955  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min         0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%     54201.500000 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%     84692.000000  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%    139320.500000  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max    172792.000000  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5            V6            V7            V8            V9  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean   9.604066e-16  1.490107e-15 -5.556467e-16  1.177556e-16 -2.406455e-15
# ...

# %%
df.index
# Out:
# RangeIndex(start=0, stop=284807, step=1)

# %%
df.V1
# Out:
# 0         -1.359807
# 1          1.191857
# 2         -1.358354
# 3         -0.966272
# 4         -1.158233
#             ...
# 284802   -11.881118
# 284803    -0.732789
# 284804     1.919565
# 284805    -0.240440
# 284806    -0.533413
# Name: V1, Length: 284807, dtype: float64

# %%
df.Amount
# Out:
# 0         149.62
# 1           2.69
# 2         378.66
# 3         123.50
# 4          69.99
#            ...
# 284802      0.77
# 284803     24.79
# 284804     67.88
# 284805     10.00
# 284806    217.00
# Name: Amount, Length: 284807, dtype: float64

# %%
df.Time
# Out:
# 0              0.0
# 1              0.0
# 2              1.0
# 3              1.0
# 4              2.0
#             ...
# 284802    172786.0
# 284803    172787.0
# 284804    172788.0
# 284805    172788.0
# 284806    172792.0
# Name: Time, Length: 284807, dtype: float64

# %%
df['Time'].mean()
# Out:
# 94813.85957508067

# %%
df.Time.std()
# Out:
# 47488.14595456617

# %%
df.Amount.mean()
# Out:
# 88.34961925093133

# %%
df.Amount.std()
# Out:
# 250.1201092401885

# %%
df.columns  # for checking names of column
# Out:
# Index(['Time', 'V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9', 'V10',
#        'V11', 'V12', 'V13', 'V14', 'V15', 'V16', 'V17', 'V18', 'V19', 'V20',
#        'V21', 'V22', 'V23', 'V24', 'V25', 'V26', 'V27', 'V28', 'Amount',
#        'Class'],
#       dtype='object')

# %%
df.isnull().sum().max()  # for identifying the how many null values are there
# Out:
# 0

# %%
print('No Frauds', round(df['Class'].value_counts()[0]/len(df)*100,2))   #calculating percentage of no frauds class...2 denotes the no. of classes  [0 denotes assign class for no frauds]
# Out:
# No Frauds 99.83

# %%
print('Frauds', round(df['Class'].value_counts()[1]/len(df)*100,2))    #[1] denotes class assign for frauds class
# Out:
# Frauds 0.17

# %% [markdown]
# ## Data Visualization

# %%
plt.rcdefaults()
Class = ('1','0')
y_pos = np.arange(len(Class))
x_pos = (0,1)

plt.xticks(y_pos, Class)
plt.ylabel('Class length')
plt.title('% distribution of dataset')
plt.bar(y_pos,x_pos, align ='center', alpha =0.5)
plt.show()

# %%
fig, ax = plt.subplots(1, 2, figsize=(18,4))

amount_val = df['Amount'].values
time_val = df['Time'].values

sns.distplot(amount_val, ax=ax[0], color='r')
ax[0].set_title('Distribution of Transaction Amount', fontsize=14)
ax[0].set_xlim([min(amount_val), max(amount_val)])

sns.distplot(time_val, ax=ax[1], color='b')
ax[1].set_title('Distribution of Transaction Time', fontsize=14)
ax[1].set_xlim([min(time_val), max(time_val)])
plt.show()

# %%
class_count = pd.value_counts(df['Class'], sort = False)
class_count.plot(kind = 'bar')
plt.title("Histogram ")
plt.xlabel("Class")
plt.ylabel("No.trasaction taken place")
plt.show()

# %% [markdown]
# ## Handling the unscaled variables
# As two of the variables time and amount are not scaled, I scale them by using different libraries and make new variables
# to add in existing dataframe.

# %%
from sklearn.preprocessing import StandardScaler, RobustScaler

std_scaler = StandardScaler()
rob_scaler = RobustScaler()

df['scaled_amount'] = rob_scaler.fit_transform(df['Amount'].values.reshape(-1,1))
df['scaled_time'] = rob_scaler.fit_transform(df['Time'].values.reshape(-1,1))

df.drop(['Time','Amount'], axis=1, inplace=True)

# %%
scaled_amount = df['scaled_amount']
scaled_time = df['scaled_time']     #### this will attach the scaled columns in dataframe

print(scaled_amount)
print (scaled_time)
df.drop(['scaled_amount', 'scaled_time'], axis=1, inplace=True)  #### this is drop and folowing inser command used to put 
                                                                ###scaled columns on 0 and 1 locations of table
df.insert(0, 'scaled_amount', scaled_amount)
df.insert(1, 'scaled_time', scaled_time)

# Amount and Time are Scaled!

df.head(100)
# Out:
# 0         1.783274
# 1        -0.269825
# 2         4.983721
# 3         1.418291
# 4         0.670579
#             ...
# 284802   -0.296653
# 284803    0.038986
# 284804    0.641096
# 284805   -0.167680
# 284806    2.724796
# Name: scaled_amount, Length: 284807, dtype: float64
# 0        -0.994983
# 1        -0.994983
# 2        -0.994972
# 3        -0.994972
# 4        -0.994960
#             ...
# 284802    1.034951
# 284803    1.034963
# 284804    1.034975
# 284805    1.034975
# 284806    1.035022
# Name: scaled_time, Length: 284807, dtype: float64
#     scaled_amount  scaled_time        V1        V2        V3        V4  \
# 0        1.783274    -0.994983 -1.359807 -0.072781  2.536347  1.378155
# 1       -0.269825    -0.994983  1.191857  0.266151  0.166480  0.448154
# 2        4.983721    -0.994972 -1.358354 -1.340163  1.773209  0.379780
# 3        1.418291    -0.994972 -0.966272 -0.185226  1.792993 -0.863291
# ...

# %%
print(df['Class'].value_counts()/len(df))
df['Class'].value_counts()[1]
# Out:
# 0    0.998273
# 1    0.001727
# Name: Class, dtype: float64
# 492

# %% [markdown]
# ## Handling the Imbalanced dataset
# There are many techniques such as under sampling, over sampling and SMOTE to handle the imbalanced data. If one performs
# model fitting on imbalanced dataset then it will give overfitting or inf accuracy.

# %%
df = df.sample(frac=1)

fraud_df = df.loc[df['Class'] == 1]
non_fraud_df = df.loc[df['Class'] == 0][:492]   #### undersampling is done...data limits to 492 same as fraud

normal_distributed_df = pd.concat([fraud_df, non_fraud_df])  ##pd.concat adds the the colum with optional set along other axes

# Shuffle dataframe rows
new_df = normal_distributed_df.sample(frac=1, random_state=42)

new_df.head()
# Out:
#         scaled_amount  scaled_time         V1         V2         V3  \
# 268661      -0.261720     0.923789  -0.104240   0.763092  -0.857882
# 154684      -0.307273     0.210059 -28.709229  22.057729 -27.855811
# 167659       1.646615     0.400980  -0.096090  -0.602255   1.731803
# 52466       -0.293440    -0.460872  -1.476893   2.122314  -1.229470
# 6336        -0.293440    -0.906366   0.329594   3.712889  -5.775935
#
#                V4         V5        V6         V7         V8  ...        V20  \
# 268661  -0.846048   1.488166 -0.043359   0.748376   0.105133  ...  -0.022328
# 154684  11.845013 -18.983813  6.474115 -43.557242 -41.044261  ...  11.059004
# 167659  -0.091844  -1.171562  1.228021  -0.389165   0.348602  ...  -0.290387
# 52466    1.201849  -0.343264 -1.317704  -1.528142  -0.620953  ...   0.276893
# 6336     6.078266   1.667359 -2.420168  -0.812891   0.133080  ...   0.269773
#
#               V21       V22       V23       V24       V25       V26       V27  \
# ...

# %%
print('Distribution of the Classes in the subsample dataset')
print(new_df['Class'].value_counts()/len(new_df))
# Out:
# Distribution of the Classes in the subsample dataset
# 1    0.5
# 0    0.5
# Name: Class, dtype: float64

# %%
X = new_df.drop('Class', axis=1)
y = new_df['Class']

# %% [markdown]
# ## Splitting the dataset

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(new_df, y, test_size=0.2,random_state = 42)
X_train = X_train.drop('Class', axis=1)
X_test = X_test.drop('Class', axis=1)    ### class is dropped bcoz we are classifying it
print (X_train.shape, y_train.shape)
print (X_test.shape, y_test.shape)
# Out:
# (787, 30) (787,)
# (197, 30) (197,)

# %%
corrMatrix = df.corr()
corrMatrix
# Out:
#                scaled_amount  scaled_time            V1            V2  \
# scaled_amount       1.000000    -0.010596 -2.277087e-01 -5.314089e-01
# scaled_time        -0.010596     1.000000  1.173963e-01 -1.059333e-02
# V1                 -0.227709     0.117396  1.000000e+00 -1.163143e-16
# V2                 -0.531409    -0.010593 -1.163143e-16  1.000000e+00
# V3                 -0.210880    -0.419618 -5.303847e-16 -1.037461e-16
# V4                  0.098732    -0.105260 -2.177842e-16 -1.029360e-16
# V5                 -0.386356     0.173072  1.286559e-16  1.458226e-16
# V6                  0.215981    -0.063016  1.321464e-16  2.126136e-16
# V7                  0.397311     0.084714  1.700756e-16 -5.120642e-17
# V8                 -0.103079    -0.036949 -6.700819e-18 -5.015295e-17
# V9                 -0.044246    -0.008660  9.531972e-17 -7.763113e-17
# V10                -0.101502     0.030617  8.715238e-17 -2.698289e-16
# ...

# %%
f, (ax1, ax2) = plt.subplots(2, 1, figsize=(24,20))
sns.heatmap(corrMatrix, cmap='coolwarm_r', annot_kws={'size':50})
plt.show()

# %%
corrMatrix_new = new_df.corr()
corrMatrix_new
# Out:
#                scaled_amount  scaled_time        V1        V2        V3  \
# scaled_amount       1.000000     0.039163 -0.065080 -0.289424 -0.035702
# scaled_time         0.039163     1.000000  0.239041 -0.252194  0.168083
# V1                 -0.065080     0.239041  1.000000 -0.753262  0.877999
# V2                 -0.289424    -0.252194 -0.753262  1.000000 -0.817138
# V3                 -0.035702     0.168083  0.877999 -0.817138  1.000000
# V4                  0.037393    -0.255349 -0.604292  0.635264 -0.758439
# V5                 -0.132267     0.298293  0.853133 -0.756997  0.846182
# V6                  0.208075     0.118871  0.288004 -0.268484  0.438728
# V7                  0.159302     0.245125  0.857269 -0.832912  0.871722
# V8                 -0.000033    -0.129344 -0.074301 -0.027232 -0.166731
# V9                  0.013730     0.194840  0.643084 -0.674379  0.756403
# V10                -0.006936     0.245880  0.716324 -0.735211  0.846687
# ...

# %% [markdown]
# f, (ax1, ax2) = plt.subplots(2, 1, figsize=(24,20))
# sns.heatmap(corrMatrix_new, cmap='coolwarm_r', annot_kws={'size':50})
# plt.show()

# %% [markdown]
# ## Different Classification Techniques are Used

# %%
from sklearn.model_selection import cross_val_score
from sklearn.linear_model import LogisticRegression
from sklearn import metrics
from sklearn.metrics import f1_score
from sklearn.ensemble import RandomForestClassifier

# %%
import statsmodels.api as sm
logit_model=sm.Logit(y,X)
summary=logit_model.fit()
print(summary.summary())
# Out:
# Optimization terminated successfully.
#          Current function value: 0.128102
#          Iterations 19
#                            Logit Regression Results
# ...
# Dep. Variable:                  Class   No. Observations:                  984
# Model:                          Logit   Df Residuals:                      954
# Method:                           MLE   Df Model:                           29
# Date:                Tue, 07 Apr 2020   Pseudo R-squ.:                  0.8152
# Time:                        13:56:59   Log-Likelihood:                -126.05
# converged:                       True   LL-Null:                       -682.06
# Covariance Type:            nonrobust   LLR p-value:                1.722e-215
# ...
#                     coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# scaled_amount     1.3031      0.979      1.330      0.183      -0.617       3.223
# ...

# %% [markdown]
# ## Logistic Regression (Detailed)

# %%
logreg = LogisticRegression()

# %%
logreg = logreg.fit(X_train,y_train)
training_score = cross_val_score(logreg,X_train,y_train,cv = 5)
print(training_score)
print("Logistic Regression has", round(training_score.mean(), 2) * 100, " % accuracy")
###y_pred=logreg.predict(X_train)
# Out:
# [0.93670886 0.96202532 0.91082803 0.92993631 0.92356688]
# Logistic Regression has 93.0  % accuracy

# %%
y_pred1 = logreg.predict(X_test)
print(' Accuracy on test set: {:.2f}'.format(logreg.score(X_test, y_test)))
# Out:
#  Accuracy on test set: 0.93

# %%
from sklearn.metrics import confusion_matrix
confusion_matrix = confusion_matrix(y_test, y_pred1)
print(confusion_matrix)
# Out:
# [[86  1]
#  [13 97]]

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test, y_pred1))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.87      0.99      0.92        87
#            1       0.99      0.88      0.93       110
#
#     accuracy                           0.93       197
#    macro avg       0.93      0.94      0.93       197
# weighted avg       0.94      0.93      0.93       197

# %%
training_scores = cross_val_score(logreg, X, y, cv=5, scoring='f1_macro')
training_scores

#### training score and f1-macro(score) showing the same accuracy because dataset is balanced.
# Out:
# C:\Users\jayes\Anaconda3\envs\RandPython\lib\site-packages\sklearn\linear_model\_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# array([0.94923727, 0.95423926, 0.91362546, 0.93394888, 0.93363028])

# %%
from sklearn.metrics import roc_curve
from sklearn.model_selection import cross_val_predict
from sklearn.metrics import roc_auc_score

# %%
logit_roc_auc = roc_auc_score(y_test, logreg.predict(X_test))
false_positive_rate, true_positive_rate, thresholds = roc_curve(y_test, logreg.predict_proba(X_test)[:,1])
plt.figure()
plt.plot(false_positive_rate, true_positive_rate,label='Logistic Regression (area = %0.4f)' % logit_roc_auc)
plt.plot([0,1], [0,1],'r--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.0])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic Curve')
plt.legend(loc="lower right")
plt.show()
## blue color ROC Curve_ Curve of Probability (93% chance to classify between fraud and no_fraud)
### Higher the roc bettter the model i.e. better the classification

# %%
logreg_pred = cross_val_predict(logreg, X_train, y_train, cv=5)
from sklearn.metrics import roc_auc_score

print('Logistic Regression: ', roc_auc_score(y_train, logreg_pred))
# Out:
# Logistic Regression:  0.9321149246978218

# %% [markdown]
# ## Random Forest

# %%
## Import the model we are using
from sklearn.ensemble import RandomForestClassifier

# Instantiate model with 1000 decision trees
rf = RandomForestClassifier(n_estimators = 1000, random_state = 42)
# Train the model on training data
rf.fit(X_train, y_train)

x_pred =rf.predict(X_train)
y_pred=rf.predict(X_test)
from sklearn import metrics
# Model Accuracy 
print("% train accuracy:",metrics.accuracy_score(y_train, x_pred))
print("% test accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
# % train accuracy: 1.0
# % test accuracy: 0.9390862944162437
